# %% [markdown]
# <a href="https://colab.research.google.com/github/BandaAkshitha/Batch_4/blob/main/DAV_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]
plt.plot(x, y, marker='o', linestyle='--', color='b')
plt.title('Line Plot')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
df = pd.DataFrame({'x': [1, 2, 3, 4], 'y': [10, 20, 25, 30]})
sns.lineplot(x='x', y='y', data=df, marker='o')
plt.title('Line Plot')
plt.show()

# %%
import plotly.express as px
df = pd.DataFrame({'x': [1, 2, 3, 4], 'y': [10, 20, 25, 30]})
fig = px.line(df, x='x', y='y', title='Line Plot', markers=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]
plt.scatter(x, y, color='r', s=50)
plt.title('Scatter Plot')
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
df = pd.DataFrame({'x': [1, 2, 3, 4], 'y': [10, 20, 25, 30]})
sns.scatterplot(x='x', y='y', data=df)
plt.title('Scatter Plot')
plt.show()

# %%
import plotly.express as px
df = pd.DataFrame({'x': [1, 2, 3, 4], 'y': [10, 20, 25, 30]})
fig = px.scatter(df, x='x', y='y', title='Scatter Plot')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt
categories = ['A', 'B', 'C']
values = [4, 3, 5]
plt.bar(categories, values, color='g')
plt.title('Bar Chart')
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
df = pd.DataFrame({'categories': ['A', 'B', 'C'], 'values': [4, 3, 5]})
sns.barplot(x='categories', y='values', data=df)
plt.title('Bar Chart')
plt.show()

# %%
import plotly.express as px
df = pd.DataFrame({'categories': ['A', 'B', 'C'], 'values': [4, 3, 5]})
fig = px.bar(df, x='categories', y='values', title='Bar Chart')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt
data = [1, 2, 2, 3, 3, 3, 4]
plt.hist(data, bins=4, color='c', edgecolor='black')
plt.title('Histogram')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data = [1, 2, 2, 3, 3, 3, 4]
sns.histplot(data, bins=4, kde=True)
plt.title('Histogram')
plt.show()

# %%
import plotly.express as px
data = [1, 2, 2, 3, 3, 3, 4]
fig = px.histogram(data, nbins=4, title='Histogram')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
data = np.random.rand(5, 5)
plt.imshow(data, cmap='viridis')
plt.colorbar()
plt.title('Heatmap')
plt.show()

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
data = np.random.rand(5, 5)
sns.heatmap(data, annot=True, cmap='coolwarm')
plt.title('Heatmap')
plt.show()

# %%
import plotly.express as px
import numpy as np
data = np.random.rand(5, 5)
fig = px.imshow(data, title='Heatmap', color_continuous_scale='Viridis')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt
data = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
plt.boxplot(data)
plt.title('Box Plot')
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
df = pd.DataFrame({'Group': ['A']*3 + ['B']*3 + ['C']*3, 'Value': [1,2,3,4,5,6,7,8,9]})
sns.boxplot(x='Group', y='Value', data=df)
plt.title('Box Plot')
plt.show()

# %%
import plotly.express as px
import pandas as pd
df = pd.DataFrame({'Group': ['A']*3 + ['B']*3 + ['C']*3, 'Value': [1,2,3,4,5,6,7,8,9]})
fig = px.box(df, x='Group', y='Value', title='Box Plot')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
